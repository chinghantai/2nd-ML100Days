# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y-yp) ** 2 ) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 236.464
# The Mean absolute error is 12.493

# %% [markdown]
# # 作業1
#
# 資料選擇:
# https://www.kaggle.com/qks1lver/amex-nyse-nasdaq-stock-histories
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 本組資料主要蒐集美國證券市場AMEX,NYSE,NASDAQ上市股票歷史資料，是研究機器學習是否適用於金融投資的第一步。本人對於機器學習是否能夠應用於投資相當有興趣，特別是我們是否可以透過機器學習獲取優於大盤的報酬率。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料來自於真實的股票交易資訊，根據作者Jiun Yen描述，目前大多數資料來自於Yahoo Finance，但部分代碼無法在Yahoo Finance查詢，作者預期將會利用CNN Money擷取資料。
#
#
# 3. 蒐集而來的資料型態為何
# 大多數股價相關歷史資料以CSV方式儲存，而相關股票的list則是以txt檔案儲存
#
# 4. 這組資料想解決的問題如何評估
# 本組資料主要提供最基本的美國股票交易資訊，資料庫內並沒有提出主要用於哪方面之研究。
# 本人認為，交易資訊提供了股票最基本的漲跌動態，雖然股票漲跌無法以單一個股之價量分析解釋，或許可從大數據中衍生的資料(如技術分析等)觀察出些許的規律性。
# 本人主要希望利用機器學習獲取超越大盤的報酬率，因此可用大盤之歷史資料作為標準，以回測方式評估其結果。

# %% [markdown]
# # 作業2
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 核心問題為如何使用數據以提升業績。所謂提升業績應以提升淨利潤為主要目的，亦即是在提升總營收的同時也須兼顧經營效率。因此，可能分析的範圍包含增加/減少車隊規模、增加/減少/調整車隊載客時間、以及決定載客範圍及價格調整。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 資料可透過車隊之載客資訊蒐集，或者參考同業載客資訊、甚至可參考不同地區的載客資訊。
# 資料範圍包含每單位時間載客數量、客人上下車地點統計、不同時段載客數量、距離、以及目的地等。
# 透過載客資訊可能可以更加精確判斷以及預測載客路線、不同時間點需要的車隊規模、以及可能的競爭狀況(以決定增加/減少車隊規模)。除此之外，可透過資料分析客戶對於價格之敏感度、進而達到價格調整的目的。
#
# 3. 蒐集而來的資料型態為何
# 載客數量、距離可為最基本的數字資料型態、而上下車地點等可能需要透過定位轉換為不同的標籤型態。
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 若僅有車隊本身資訊，則可能評估方式為重新規劃路線以及人力，看是否有機會提升車隊使用效率增加利潤。或以分析之結果實際調整人力、路線及價格驗證分析假設結果。
# 若同時可蒐集同業之資料，應可更精確分析及驗證競爭狀態。
